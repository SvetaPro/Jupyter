# %%
import requests
import xmltodict

url = "http://www.cbr.ru/scripts/XML_daily.asp"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<?xml version="1.0" encoding="windows-1251"?><ValCurs Date="17.02.2024" name="Foreign Currency Market"><Valute ID="R01010"><NumCode>036</NumCode><CharCode>AUD</CharCode><Nominal>1</Nominal><Name>\xc0\xe2\xf1\xf2\xf0\xe0\xeb\xe8\xe9\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>60,3236</Value><VunitRate>60,3236</VunitRate></Valute><Valute ID="R01020A"><NumCode>944</NumCode><CharCode>AZN</CharCode><Nominal>1</Nominal><Name>\xc0\xe7\xe5\xf0\xe1\xe0\xe9\xe4\xe6\xe0\xed\xf1\xea\xe8\xe9 \xec\xe0\xed\xe0\xf2</Name><Value>54,4407</Value><VunitRate>54,4407</VunitRate></Valute><Valute ID="R01035"><NumCode>826</NumCode><CharCode>GBP</CharCode><Nominal>1</Nominal><Name>\xd4\xf3\xed\xf2 \xf1\xf2\xe5\xf0\xeb\xe8\xed\xe3\xee\xe2 \xd1\xee\xe5\xe4\xe8\xed\xe5\xed\xed\xee\xe3\xee \xea\xee\xf0\xee\xeb\xe5\xe2\xf1\xf2\xe2\xe0</Name><Value>116,4732</Value><VunitRate>116,4732</VunitRate></Valute><Valute ID="R01060"><NumCode>051</NumCode><CharCode>AMD</CharCode><Nominal>100</Nominal><Name>\xc0\xf0\xec\xff\xed\xf1\xea\xe8\xf5 \xe4\xf0\xe0\xec\xee\xe2</Name><Value>22,8844</Value><VunitRate>0,228844</VunitRate></Valute><Valute ID="R01090B"><NumCode>933</NumCode><CharCode>BYN</CharCode><Nominal>1</Nominal><Name>\xc1\xe5\xeb\xee\xf0\xf3\xf1\xf1\xea\xe8\xe9 \xf0\xf3\xe1\xeb\xfc</Name><Value>28,5478</Value><VunitRate>28,5478</VunitRate></Valute><Valute ID="R01100"><NumCode>975</NumCode><CharCode>BGN</CharCode><Nominal>1</Nominal><Name>\xc1\xee\xeb\xe3\xe0\xf0\xf1\xea\xe8\xe9 \xeb\xe5\xe2</Name><Value>50,8356</Value><VunitRate>50,8356</VunitRate></Valute><Valute ID="R01115"><NumCode>986</NumCode><CharCode>BRL</CharCode><Nominal>1</Nominal><Name>\xc1\xf0\xe0\xe7\xe8\xeb\xfc\xf1\xea\xe8\xe9 \xf0\xe5\xe0\xeb</Name><Value>18,6189</Value><VunitRate>18,6189</VunitRate></Valute><Valute ID="R01135"><NumCode>348</NumCode><CharCode>HUF</CharCode><Nominal>100</Nominal><Name>\xc2\xe5\xed\xe3\xe5\xf0\xf1\xea\xe8\xf5 \xf4\xee\xf0\xe8\xed\xf2\xee\xe2</Name><Value>25,5915</Value><VunitRate>0,255915</VunitRate></Valute><Valute ID="R01150"><NumCode>704</NumCode><CharCode>VND</CharCode><Nominal>10000</Nominal><Name>\xc2\xfc\xe5\xf2\xed\xe0\xec\xf1\xea\xe8\xf5 \xe4\xee\xed\xe3\xee\xe2</Name><Value>38,6088</Value><VunitRate>0,00386088</VunitRate></Valute><Valute ID="R01200"><NumCode>344</NumCode><CharCode>HKD</CharCode><Nominal>1</Nominal><Name>\xc3\xee\xed\xea\xee\xed\xe3\xf1\xea\xe8\xe9 \xe4\xee\xeb\xeb\xe0\xf0</Name><Value>11,8531</Value><VunitRate>11,8531</VunitRate></Valute><Valute ID="R01210"><NumCode>981</NumCode><CharCode>GEL</CharCode><Nominal>1</Nominal><Name>\xc3\xf0\xf3\xe7\xe8\xed\xf1\xea\xe8\xe9 \xeb\xe0\xf0\xe8</Name><Value>34,9863</Value><VunitRate>34,9863</VunitRate></Valute><Valute ID="R01215"><NumCode>208</NumCode><CharCode>DKK</CharCode><Nominal>1</Nominal><Name>\xc4\xe0\xf2\xf1\xea\xe0\xff \xea\xf0\xee\xed\xe0</Name><Value>13,3373</Value><VunitRate>13,3373</VunitRate></Valute><Valute ID="R01230"><NumCode>784</NumCode><CharCode>AED</CharCode><Nominal>1</Nominal><Name>\xc4\xe8\xf0\xf5\xe0\xec \xce\xc0\xdd</Name><Value>25,2006</Value><VunitRate>25,2006</VunitRate></Valute><Valute ID="R01235"><NumCode>840</NumCode><CharCode>USD</CharCode><Nominal>1</Nominal><Name>\xc4\xee\xeb\xeb\xe0\xf0 \xd1\xd8\xc0</Name><Value>92,5492</Value><VunitRate>92,5492</VunitRate></Valute><Valute ID="R01239"><NumCode>978</NumCode><CharCode>EUR</CharCode><Nominal>1</Nominal><Name>\xc5\xe2\xf0\xee</Name><Value>99,3523</Value><VunitRate>99,3523</VunitRate></Valute><Valute ID="R01240"><NumCode>818</NumCode><CharCode>EGP</CharCode><Nominal>10</Nominal><Name>\xc5\xe3\xe8\xef\xe5\xf2\xf1\xea\xe8\xf5 \xf4\xf3\xed\xf2\xee\xe2</Name><Value>29,9581</Value><VunitRate>2,99581</VunitRate></Valute><Valute ID="R01270"><NumCode>356</NumCode><CharCode>INR</CharCode><Nominal>10</Nominal><Name>\xc8\xed\xe4\xe8\xe9\xf1\xea\xe8\xf5 \xf0\xf3\xef\xe8\xe9</Name><Value>11,1506</Value><VunitRate>1,11506</VunitRate></Valute><Valute ID="R01280"><NumCode>360</NumCode><CharCode>IDR</CharCode><Nominal>100 ...

# %%
data = xmltodict.parse(response.content)
data
# Out:
# {'ValCurs': {'@Date': '17.02.2024',
#   '@name': 'Foreign Currency Market',
#   'Valute': [{'@ID': 'R01010',
#     'NumCode': '036',
#     'CharCode': 'AUD',
#     'Nominal': '1',
#     'Name': 'Австралийский доллар',
#     'Value': '60,3236',
#     'VunitRate': '60,3236'},
#    {'@ID': 'R01020A',
#     'NumCode': '944',
#     'CharCode': 'AZN',
#     'Nominal': '1',
#     'Name': 'Азербайджанский манат',
#     'Value': '54,4407',
#     'VunitRate': '54,4407'},
#    {'@ID': 'R01035',
#     'NumCode': '826',
#     'CharCode': 'GBP',
#     'Nominal': '1',
#     'Name': 'Фунт стерлингов Соединенного королевства',
#     'Value': '116,4732',
#     'VunitRate': '116,4732'},
#    {'@ID': 'R01060',
#     'NumCode': '051',
#     'CharCode': 'AMD',
#     'Nominal': '100',
#     'Name': 'Армянских драмов',
#     'Value': '22,8844',
#     'VunitRate': '0,228844'},
#    {'@ID': 'R01090B',
#     'NumCode': '933',
#     'CharCode': 'BYN',
#     'Nominal': '1',
#     'Name': 'Белорусский рубль',
#     'Value': '28,5478',
#     'VunitRate': '28,5478'},
#    {'@ID': 'R01100',
#     'NumCode': '975',
#     'CharCode': 'BGN',
#     'Nominal': '1',
#     'Name': 'Болгарский лев',
#     'Value': '50,8356',
#     'VunitRate': '50,8356'},
#    {'@ID': 'R01115',
#     'NumCode': '986',
#     'CharCode': 'BRL',
#     'Nominal': '1',
#     'Name': 'Бразильский реал',
#     'Value': '18,6189',
#     'VunitRate': '18,6189'},
#    {'@ID': 'R01135',
#     'NumCode': '348',
#     'CharCode': 'HUF',
#     'Nominal': '100',
#     'Name': 'Венгерских форинтов',
#     'Value': '25,5915',
#     'VunitRate': '0,255915'},
#    {'@ID': 'R01150',
#     'NumCode': '704',
#     'CharCode': 'VND',
#     'Nominal': '10000',
#     'Name': 'Вьетнамских донгов',
#     'Value': '38,6088',
#     'VunitRate': '0,00386088'},
#    {'@ID': 'R01200',
#     'NumCode': '344',
#     'CharCode': 'HKD',
#     'Nominal': '1',
#     'Name': 'Гонконгский доллар',
#     'Value': '11,8531',
#     'VunitRate': '11,8531'},
#    {'@ID': 'R01210',
#     'NumCode': '981',
#     'CharCode': 'GEL',
#     'Nominal': '1',
#     'Name': 'Грузинский лари',
#     'Value': '34,9863',
#     'VunitRate': '34,9863'},
#    {'@ID': 'R01215',
#     'NumCode': '208',
#     'CharCode': 'DKK',
#     'Nominal': '1',
#     'Name': 'Датская крона',
#     'Value': '13,3373',
#     'VunitRate': '13,3373'},
#    {'@ID': 'R01230',
#     'NumCode': '784',
#     'CharCode': 'AED',
#     'Nominal': '1',
#     'Name': 'Дирхам ОАЭ',
#     'Value': '25,2006',
#     'VunitRate': '25,2006'},
#    {'@ID': 'R01235',
#     'NumCode': '840',
#     'CharCode': 'USD',
#     'Nominal': '1',
#     'Name': 'Доллар США',
#     'Value': '92,5492',
#     'VunitRate': '92,5492'},
#    {'@ID': 'R01239',
#     'NumCode': '978',
#     'CharCode': 'EUR',
#     'Nominal': '1',
#     'Name': 'Евро',
#     'Value': '99,3523',
#     'VunitRate': '99,3523'},
#    {'@ID': 'R01240',
#     'NumCode': '818',
#     'CharCode': 'EGP',
#     'Nominal': '10',
#     'Name': 'Египетских фунтов',
#     'Value': '29,9581',
#     'VunitRate': '2,99581'},
#    {'@ID': 'R01270',
#     'NumCode': '356',
#     'CharCode': 'INR',
#     'Nominal': '10',
#     'Name': 'Индийских рупий',
#     'Value': '11,1506',
#     'VunitRate': '1,11506'},
#    {'@ID': 'R01280',
#     'NumCode': '360',
#     'CharCode': 'IDR',
#     'Nominal': '10000',
#     'Name': 'Индонезийских рупий',
#     'Value': '59,3036',
#     'VunitRate': '0,00593036'},
#    {'@ID': 'R01335',
#     'NumCode': '398',
#     'CharCode': 'KZT',
#     'Nominal': '100',
#     'Name': 'Казахстанских тенге',
#     'Value': '20,6555',
#     'VunitRate': '0,206555'},
#    {'@ID': 'R01350',
#     'NumCode': '124',
#     'CharCode': 'CAD',
#     'Nominal': '1',
#     'Name': 'Канадский доллар',
#     'Value': '68,5905',
#     'VunitRate': '68,5905'},
#    {'@ID': 'R01355',
#     'NumCode': '634',
#     'CharCode': 'QAR',
#     'Nominal': '1',
#     'Name': 'Катарский риал',
#     'Value': '25,4256',
#     'VunitRate': '25,4256'},
#    {'@ID': 'R01370',
#     'NumCode': '417',
#     'CharCode': 'KGS',
#     'Nominal': '10',
#     'Name': 'Киргизских сомов',
#     'Value': '10,3488',
#     'VunitRate': '1,03488'},
#    {'@ID': 'R01375',
#     'NumCode': '156',
#     'CharCode': 'CNY',
#     'Nominal': '1',
#     'Name': 'Китайский юань',
#     'Value': '12,7418',
#     'VunitRate': '12,7418'},
#    {'@ID': 'R01500',
#     'NumCode': '498',
#     'CharCode': 'MDL',
#     'Nominal': '10',
#     'Name': 'Молдавских леев',
#     'Value': '51,8407',
#     'VunitRate': '5,18407'},
#    {'@ID': 'R01530',
#     'NumCode': '554',
#     'CharCode': 'NZD',
#     'Nominal': '1',
#     'Name': 'Новозеландский доллар',
#     'Value': '56,4087',
#     'VunitRate': '56,4087'},
#    {'@ID': 'R01535',
#     'NumCode': '578',
#     'CharCode': 'NOK',
#     'Nominal': '10',
#     'Name': 'Норвежских крон',
#     'Value': '87,5145',
#     'VunitRate': '8,75145'},
#    {'@ID': 'R01565',
#     'NumCode': '985',
#     'CharCode': 'PLN',
#     'Nominal': '1',
#     'Name': 'Польский злотый',
#     'Value': '22,9508',
#     'VunitRate': '22,9508'},
#    {'@ID': 'R01585F',
#     'NumCode': '946',
#     'CharCode': 'RON',
#     'Nominal': '1',
#     'Name': 'Румынский лей',
#     'Value': '20,0293',
#     'VunitRate': '20,0293'},
#    {'@ID': 'R01589',
#     'NumCode': '960',
#     'CharCode': 'XDR',
#     'Nominal': '1',
#     'Name': 'СДР (специальные права заимствования)',
#     'Value': '122,4259',
#     'VunitRate': '122,4259'},
#    {'@ID': 'R01625',
#     'NumCode': '702',
#     'CharCode': 'SGD',
#     'Nominal': '1',
#     'Name': 'Сингапурский доллар',
#     'Value': '68,7025',
#     'VunitRate': '68,7025'},
#    {'@ID': 'R01670',
#     'NumCode': '972',
#     'CharCode': 'TJS',
#     'Nominal': '10',
#     'Name': 'Таджикских сомони',
#     'Value': '84,4905',
#     'VunitRate': '8,44905'},
#    {'@ID': 'R01675',
#     'NumCode': '764',
#     'CharCode': 'THB',
#     'Nominal': '10',
#     'Name': 'Таиландских батов',
#     'Value': '25,6293',
#     'VunitRate': '2,56293'},
#    {'@ID': 'R01700J',
#     'NumCode': '949',
#     'CharCode': 'TRY',
#     'Nominal': '10',
#     'Name': 'Турецких лир',
#     'Value': '30,1223',
#     'VunitRate': '3,01223'},
#    {'@ID': 'R01710A',
#     'NumCode': '934',
#     'CharCode': 'TMT',
#     'Nominal': '1',
#     'Name': 'Новый туркменский манат',
#     'Value': '26,4426',
#     'VunitRate': '26,4426'},
#    {'@ID': 'R01717',
#     'NumCode': '860',
#     'CharCode': 'UZS',
#     'Nominal': '10000',
#     'Name': 'Узбекских сумов',
#     'Value': '74,0571',
#     'VunitRate': '0,00740571'},
#    {'@ID': 'R01720',
#     'NumCode': '980',
#     'CharCode': 'UAH',
#     'Nominal': '10',
#     'Name': 'Украинских гривен',
#     'Value': '24,3882',
#     'VunitRate': '2,43882'},
#    {'@ID': 'R01760',
#     'NumCode': '203',
#     'CharCode': 'CZK',
#     'Nominal': '10',
#     'Name': 'Чешских крон',
#     'Value': '39,1312',
#     'VunitRate': '3,91312'},
#    {'@ID': 'R01770',
#     'NumCode': '752',
#     'CharCode': 'SEK',
#     'Nominal': '10',
#     'Name': 'Шведских крон',
#     'Value': '88,3196',
#     'VunitRate': '8,83196'},
#    {'@ID': 'R01775',
#     'NumCode': '756',
#     'CharCode': 'CHF',
#     'Nominal': '1',
#     'Name': 'Швейцарский франк',
#     'Value': '105,0263',
#     'VunitRate': '105,0263'},
#    {'@ID': 'R01805F',
#     'NumCode': '941',
#     'CharCode': 'RSD',
#     'Nominal': '100',
#     'Name': 'Сербских динаров',
#     'Value': '84,6334',
#     'VunitRate': '0,846334'},
#    {'@ID': 'R01810',
#     'NumCode': '710',
#     'CharCode': 'ZAR',
#     'Nominal': '10',
#     'Name': 'Южноафриканских рэндов',
#     'Value': '49,0062',
#     'VunitRate': '4,90062'},
#    {'@ID': 'R01815',
#     'NumCode': '410',
#     'CharCode': 'KRW',
#     'Nominal': '1000',
#     'Name': 'Вон Республики Корея',
#     'Value': '69,3045',
#     'VunitRate': '0,0693045'},
#    {'@ID': 'R01820',
#     'NumCode': '392',
#     'CharCode': 'JPY',
#     'Nominal': '100',
#     'Name': 'Японских иен',
#     'Value': '61,6378',
#     'VunitRate': '0,616378'}]}}

# %%
items = []
for item in data['ValCurs']['Valute']:
    items.append(item)
items
# Out:
# [{'@ID': 'R01010',
#   'NumCode': '036',
#   'CharCode': 'AUD',
#   'Nominal': '1',
#   'Name': 'Австралийский доллар',
#   'Value': '60,3236',
#   'VunitRate': '60,3236'},
#  {'@ID': 'R01020A',
#   'NumCode': '944',
#   'CharCode': 'AZN',
#   'Nominal': '1',
#   'Name': 'Азербайджанский манат',
#   'Value': '54,4407',
#   'VunitRate': '54,4407'},
#  {'@ID': 'R01035',
#   'NumCode': '826',
#   'CharCode': 'GBP',
#   'Nominal': '1',
#   'Name': 'Фунт стерлингов Соединенного королевства',
#   'Value': '116,4732',
#   'VunitRate': '116,4732'},
#  {'@ID': 'R01060',
#   'NumCode': '051',
#   'CharCode': 'AMD',
#   'Nominal': '100',
#   'Name': 'Армянских драмов',
#   'Value': '22,8844',
#   'VunitRate': '0,228844'},
#  {'@ID': 'R01090B',
#   'NumCode': '933',
#   'CharCode': 'BYN',
#   'Nominal': '1',
#   'Name': 'Белорусский рубль',
#   'Value': '28,5478',
#   'VunitRate': '28,5478'},
#  {'@ID': 'R01100',
#   'NumCode': '975',
#   'CharCode': 'BGN',
#   'Nominal': '1',
#   'Name': 'Болгарский лев',
#   'Value': '50,8356',
#   'VunitRate': '50,8356'},
#  {'@ID': 'R01115',
#   'NumCode': '986',
#   'CharCode': 'BRL',
#   'Nominal': '1',
#   'Name': 'Бразильский реал',
#   'Value': '18,6189',
#   'VunitRate': '18,6189'},
#  {'@ID': 'R01135',
#   'NumCode': '348',
#   'CharCode': 'HUF',
#   'Nominal': '100',
#   'Name': 'Венгерских форинтов',
#   'Value': '25,5915',
#   'VunitRate': '0,255915'},
#  {'@ID': 'R01150',
#   'NumCode': '704',
#   'CharCode': 'VND',
#   'Nominal': '10000',
#   'Name': 'Вьетнамских донгов',
#   'Value': '38,6088',
#   'VunitRate': '0,00386088'},
#  {'@ID': 'R01200',
#   'NumCode': '344',
#   'CharCode': 'HKD',
#   'Nominal': '1',
#   'Name': 'Гонконгский доллар',
#   'Value': '11,8531',
#   'VunitRate': '11,8531'},
#  {'@ID': 'R01210',
#   'NumCode': '981',
#   'CharCode': 'GEL',
#   'Nominal': '1',
#   'Name': 'Грузинский лари',
#   'Value': '34,9863',
#   'VunitRate': '34,9863'},
#  {'@ID': 'R01215',
#   'NumCode': '208',
#   'CharCode': 'DKK',
#   'Nominal': '1',
#   'Name': 'Датская крона',
#   'Value': '13,3373',
#   'VunitRate': '13,3373'},
#  {'@ID': 'R01230',
#   'NumCode': '784',
#   'CharCode': 'AED',
#   'Nominal': '1',
#   'Name': 'Дирхам ОАЭ',
#   'Value': '25,2006',
#   'VunitRate': '25,2006'},
#  {'@ID': 'R01235',
#   'NumCode': '840',
#   'CharCode': 'USD',
#   'Nominal': '1',
#   'Name': 'Доллар США',
#   'Value': '92,5492',
#   'VunitRate': '92,5492'},
#  {'@ID': 'R01239',
#   'NumCode': '978',
#   'CharCode': 'EUR',
#   'Nominal': '1',
#   'Name': 'Евро',
#   'Value': '99,3523',
#   'VunitRate': '99,3523'},
#  {'@ID': 'R01240',
#   'NumCode': '818',
#   'CharCode': 'EGP',
#   'Nominal': '10',
#   'Name': 'Египетских фунтов',
#   'Value': '29,9581',
#   'VunitRate': '2,99581'},
#  {'@ID': 'R01270',
#   'NumCode': '356',
#   'CharCode': 'INR',
#   'Nominal': '10',
#   'Name': 'Индийских рупий',
#   'Value': '11,1506',
#   'VunitRate': '1,11506'},
#  {'@ID': 'R01280',
#   'NumCode': '360',
#   'CharCode': 'IDR',
#   'Nominal': '10000',
#   'Name': 'Индонезийских рупий',
#   'Value': '59,3036',
#   'VunitRate': '0,00593036'},
#  {'@ID': 'R01335',
#   'NumCode': '398',
#   'CharCode': 'KZT',
#   'Nominal': '100',
#   'Name': 'Казахстанских тенге',
#   'Value': '20,6555',
#   'VunitRate': '0,206555'},
#  {'@ID': 'R01350',
#   'NumCode': '124',
#   'CharCode': 'CAD',
#   'Nominal': '1',
#   'Name': 'Канадский доллар',
#   'Value': '68,5905',
#   'VunitRate': '68,5905'},
#  {'@ID': 'R01355',
#   'NumCode': '634',
#   'CharCode': 'QAR',
#   'Nominal': '1',
#   'Name': 'Катарский риал',
#   'Value': '25,4256',
#   'VunitRate': '25,4256'},
#  {'@ID': 'R01370',
#   'NumCode': '417',
#   'CharCode': 'KGS',
#   'Nominal': '10',
#   'Name': 'Киргизских сомов',
#   'Value': '10,3488',
#   'VunitRate': '1,03488'},
#  {'@ID': 'R01375',
#   'NumCode': '156',
#   'CharCode': 'CNY',
#   'Nominal': '1',
#   'Name': 'Китайский юань',
#   'Value': '12,7418',
#   'VunitRate': '12,7418'},
#  {'@ID': 'R01500',
#   'NumCode': '498',
#   'CharCode': 'MDL',
#   'Nominal': '10',
#   'Name': 'Молдавских леев',
#   'Value': '51,8407',
#   'VunitRate': '5,18407'},
#  {'@ID': 'R01530',
#   'NumCode': '554',
#   'CharCode': 'NZD',
#   'Nominal': '1',
#   'Name': 'Новозеландский доллар',
#   'Value': '56,4087',
#   'VunitRate': '56,4087'},
#  {'@ID': 'R01535',
#   'NumCode': '578',
#   'CharCode': 'NOK',
#   'Nominal': '10',
#   'Name': 'Норвежских крон',
#   'Value': '87,5145',
#   'VunitRate': '8,75145'},
#  {'@ID': 'R01565',
#   'NumCode': '985',
#   'CharCode': 'PLN',
#   'Nominal': '1',
#   'Name': 'Польский злотый',
#   'Value': '22,9508',
#   'VunitRate': '22,9508'},
#  {'@ID': 'R01585F',
#   'NumCode': '946',
#   'CharCode': 'RON',
#   'Nominal': '1',
#   'Name': 'Румынский лей',
#   'Value': '20,0293',
#   'VunitRate': '20,0293'},
#  {'@ID': 'R01589',
#   'NumCode': '960',
#   'CharCode': 'XDR',
#   'Nominal': '1',
#   'Name': 'СДР (специальные права заимствования)',
#   'Value': '122,4259',
#   'VunitRate': '122,4259'},
#  {'@ID': 'R01625',
#   'NumCode': '702',
#   'CharCode': 'SGD',
#   'Nominal': '1',
#   'Name': 'Сингапурский доллар',
#   'Value': '68,7025',
#   'VunitRate': '68,7025'},
#  {'@ID': 'R01670',
#   'NumCode': '972',
#   'CharCode': 'TJS',
#   'Nominal': '10',
#   'Name': 'Таджикских сомони',
#   'Value': '84,4905',
#   'VunitRate': '8,44905'},
#  {'@ID': 'R01675',
#   'NumCode': '764',
#   'CharCode': 'THB',
#   'Nominal': '10',
#   'Name': 'Таиландских батов',
#   'Value': '25,6293',
#   'VunitRate': '2,56293'},
#  {'@ID': 'R01700J',
#   'NumCode': '949',
#   'CharCode': 'TRY',
#   'Nominal': '10',
#   'Name': 'Турецких лир',
#   'Value': '30,1223',
#   'VunitRate': '3,01223'},
#  {'@ID': 'R01710A',
#   'NumCode': '934',
#   'CharCode': 'TMT',
#   'Nominal': '1',
#   'Name': 'Новый туркменский манат',
#   'Value': '26,4426',
#   'VunitRate': '26,4426'},
#  {'@ID': 'R01717',
#   'NumCode': '860',
#   'CharCode': 'UZS',
#   'Nominal': '10000',
#   'Name': 'Узбекских сумов',
#   'Value': '74,0571',
#   'VunitRate': '0,00740571'},
#  {'@ID': 'R01720',
#   'NumCode': '980',
#   'CharCode': 'UAH',
#   'Nominal': '10',
#   'Name': 'Украинских гривен',
#   'Value': '24,3882',
#   'VunitRate': '2,43882'},
#  {'@ID': 'R01760',
#   'NumCode': '203',
#   'CharCode': 'CZK',
#   'Nominal': '10',
#   'Name': 'Чешских крон',
#   'Value': '39,1312',
#   'VunitRate': '3,91312'},
#  {'@ID': 'R01770',
#   'NumCode': '752',
#   'CharCode': 'SEK',
#   'Nominal': '10',
#   'Name': 'Шведских крон',
#   'Value': '88,3196',
#   'VunitRate': '8,83196'},
#  {'@ID': 'R01775',
#   'NumCode': '756',
#   'CharCode': 'CHF',
#   'Nominal': '1',
#   'Name': 'Швейцарский франк',
#   'Value': '105,0263',
#   'VunitRate': '105,0263'},
#  {'@ID': 'R01805F',
#   'NumCode': '941',
#   'CharCode': 'RSD',
#   'Nominal': '100',
#   'Name': 'Сербских динаров',
#   'Value': '84,6334',
#   'VunitRate': '0,846334'},
#  {'@ID': 'R01810',
#   'NumCode': '710',
#   'CharCode': 'ZAR',
#   'Nominal': '10',
#   'Name': 'Южноафриканских рэндов',
#   'Value': '49,0062',
#   'VunitRate': '4,90062'},
#  {'@ID': 'R01815',
#   'NumCode': '410',
#   'CharCode': 'KRW',
#   'Nominal': '1000',
#   'Name': 'Вон Республики Корея',
#   'Value': '69,3045',
#   'VunitRate': '0,0693045'},
#  {'@ID': 'R01820',
#   'NumCode': '392',
#   'CharCode': 'JPY',
#   'Nominal': '100',
#   'Name': 'Японских иен',
#   'Value': '61,6378',
#   'VunitRate': '0,616378'}]

# %%
my_array = []
for item in data['ValCurs']['Valute']:
    my_set = [item['CharCode'], item['Name'], item['Value']];
    my_array.append(my_set)
    print(my_set)
# Out:
# ['AUD', 'Австралийский доллар', '60,3236']
# ['AZN', 'Азербайджанский манат', '54,4407']
# ['GBP', 'Фунт стерлингов Соединенного королевства', '116,4732']
# ['AMD', 'Армянских драмов', '22,8844']
# ['BYN', 'Белорусский рубль', '28,5478']
# ['BGN', 'Болгарский лев', '50,8356']
# ['BRL', 'Бразильский реал', '18,6189']
# ['HUF', 'Венгерских форинтов', '25,5915']
# ['VND', 'Вьетнамских донгов', '38,6088']
# ['HKD', 'Гонконгский доллар', '11,8531']
# ['GEL', 'Грузинский лари', '34,9863']
# ['DKK', 'Датская крона', '13,3373']
# ['AED', 'Дирхам ОАЭ', '25,2006']
# ['USD', 'Доллар США', '92,5492']
# ['EUR', 'Евро', '99,3523']
# ['EGP', 'Египетских фунтов', '29,9581']
# ['INR', 'Индийских рупий', '11,1506']
# ['IDR', 'Индонезийских рупий', '59,3036']
# ['KZT', 'Казахстанских тенге', '20,6555']
# ['CAD', 'Канадский доллар', '68,5905']
# ['QAR', 'Катарский риал', '25,4256']
# ['KGS', 'Киргизских сомов', '10,3488']
# ['CNY', 'Китайский юань', '12,7418']
# ['MDL', 'Молдавских леев', '51,8407']
# ['NZD', 'Новозеландский доллар', '56,4087']
# ['NOK', 'Норвежских крон', '87,5145']
# ['PLN', 'Польский злотый', '22,9508']
# ['RON', 'Румынский лей', '20,0293']
# ['XDR', 'СДР (специальные права заимствования)', '122,4259']
# ['SGD', 'Сингапурский доллар', '68,7025']
# ['TJS', 'Таджикских сомони', '84,4905']
# ['THB', 'Таиландских батов', '25,6293']
# ['TRY', 'Турецких лир', '30,1223']
# ['TMT', 'Новый туркменский манат', '26,4426']
# ['UZS', 'Узбекских сумов', '74,0571']
# ['UAH', 'Украинских гривен', '24,3882']
# ['CZK', 'Чешских крон', '39,1312']
# ['SEK', 'Шведских крон', '88,3196']
# ['CHF', 'Швейцарский франк', '105,0263']
# ['RSD', 'Сербских динаров', '84,6334']
# ['ZAR', 'Южноафриканских рэндов', '49,0062']
# ['KRW', 'Вон Республики Корея', '69,3045']
# ['JPY', 'Японских иен', '61,6378']

# %%
my_array
# Out:
# [['AUD', 'Австралийский доллар', '60,3236'],
#  ['AZN', 'Азербайджанский манат', '54,4407'],
#  ['GBP', 'Фунт стерлингов Соединенного королевства', '116,4732'],
#  ['AMD', 'Армянских драмов', '22,8844'],
#  ['BYN', 'Белорусский рубль', '28,5478'],
#  ['BGN', 'Болгарский лев', '50,8356'],
#  ['BRL', 'Бразильский реал', '18,6189'],
#  ['HUF', 'Венгерских форинтов', '25,5915'],
#  ['VND', 'Вьетнамских донгов', '38,6088'],
#  ['HKD', 'Гонконгский доллар', '11,8531'],
#  ['GEL', 'Грузинский лари', '34,9863'],
#  ['DKK', 'Датская крона', '13,3373'],
#  ['AED', 'Дирхам ОАЭ', '25,2006'],
#  ['USD', 'Доллар США', '92,5492'],
#  ['EUR', 'Евро', '99,3523'],
#  ['EGP', 'Египетских фунтов', '29,9581'],
#  ['INR', 'Индийских рупий', '11,1506'],
#  ['IDR', 'Индонезийских рупий', '59,3036'],
#  ['KZT', 'Казахстанских тенге', '20,6555'],
#  ['CAD', 'Канадский доллар', '68,5905'],
#  ['QAR', 'Катарский риал', '25,4256'],
#  ['KGS', 'Киргизских сомов', '10,3488'],
#  ['CNY', 'Китайский юань', '12,7418'],
#  ['MDL', 'Молдавских леев', '51,8407'],
#  ['NZD', 'Новозеландский доллар', '56,4087'],
#  ['NOK', 'Норвежских крон', '87,5145'],
#  ['PLN', 'Польский злотый', '22,9508'],
#  ['RON', 'Румынский лей', '20,0293'],
#  ['XDR', 'СДР (специальные права заимствования)', '122,4259'],
#  ['SGD', 'Сингапурский доллар', '68,7025'],
#  ['TJS', 'Таджикских сомони', '84,4905'],
#  ['THB', 'Таиландских батов', '25,6293'],
#  ['TRY', 'Турецких лир', '30,1223'],
#  ['TMT', 'Новый туркменский манат', '26,4426'],
#  ['UZS', 'Узбекских сумов', '74,0571'],
#  ['UAH', 'Украинских гривен', '24,3882'],
#  ['CZK', 'Чешских крон', '39,1312'],
#  ['SEK', 'Шведских крон', '88,3196'],
#  ['CHF', 'Швейцарский франк', '105,0263'],
#  ['RSD', 'Сербских динаров', '84,6334'],
#  ['ZAR', 'Южноафриканских рэндов', '49,0062'],
#  ['KRW', 'Вон Республики Корея', '69,3045'],
#  ['JPY', 'Японских иен', '61,6378']]
